# %% [markdown]
# <a href="https://colab.research.google.com/github/catpixie-47/FDIP/blob/main/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install opencv-python

# %%
pip install numpy matplotlib

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("image.png", cv2.IMREAD_COLOR)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=443x626>

# %%
blur = cv2.GaussianBlur(gray, (7,7), cv2.BORDER_DEFAULT)
cv2_imshow(blur)
# Out:
# <PIL.Image.Image image mode=L size=443x626>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=443x626>

# %%
# Histogram Equalization
hist_equalized = cv2.equalizeHist(gray)
cv2_imshow(hist_equalized)
# Out:
# <PIL.Image.Image image mode=L size=443x626>

# %%
# Contrast Stretching
min_val, max_val, _, _ = cv2.minMaxLoc(gray)
contrast_stretched = cv2.convertScaleAbs(gray, alpha=255.0/(max_val - min_val), beta=-min_val * 255.0/(max_val - min_val))
cv2_imshow(contrast_stretched)
# Out:
# <PIL.Image.Image image mode=L size=443x626>

# %%
contrast_image = cv2.convertScaleAbs(img , alpha = 1.5 , beta = 1)
cv2_imshow(contrast_image)
# Out:
# <PIL.Image.Image image mode=RGB size=443x626>
